# %%
import scipy.io as sio
import randmv_laplace as mvl
import numpy as np
a = sio.loadmat("variables.mat")

# %%
def IVA_L (X, alpha0=0.1, termThreshold=1e-6, termCrit='ChangeInCost',
           maxIter=1024, initW=[], A=[], verbose=False, whiten=False) :
    '''
    
    Solves the Independent Vector Analysis with Laplace 
    distribution given datasets. 
    
    -------------------------------------------------------------------
    -------------------------------------------------------------------
    NOTE: whitten, A, initW currently are not operational
    -------------------------------------------------------------------
    -------------------------------------------------------------------
    
    
    Inputs:
    -------------------------------------------------------------------
    
    Params = A dictionary containing the optional arguments,
        whitten = whitten the data
            (Boolean, True)
        verbose = enable print statements
            (Boolean, False)
        A = True Mixing matrix, auto sets verbose to True 
            (Matrix, [])
        initW = Initial estimates for W matrix
            (Matrix, [])
        maxIter = Maximum number of iterations
            (Integer, 1024)
        termCrit = criteria for terminating loop,
            either "ChangeInW" or "ChangeInCost".
            (String, 'ChangeInW')
        termThreshold = Termination threshold
            (Float, 1e-6)
        alpha0 = Initial step size scaling
            (Float, 0.1)
            
    X = Data observations from K data sets, i.e. X{k}=A{k}*S{k}
        where A{k} is NxN unknown invertible mixing matrix and
        S{k} is a NxT matrix with the nth row corresponding to
        T samples of nth source in the kth dataset. For IVA, 
        assumed that source is tatistically independent of all 
        sources within dataset and exactly dependent on at 
        most one source in each of the other datasets. The
        data, X, is a 3 dimensional array of dimension NxKxT. 
        The latter enforces the assumption of equal number of 
        samples in each dataset
    
    
    Outputs:
    -------------------------------------------------------------------
    W = Unmixing matrix. 
    
    cost = vector that contains costs associated to each 
        iteration
    
    '''
    
    alphaMin   = 0.1
    alphaScale = 0.9
    if (termCrit != 'ChangeInW') and (termCrit != 'ChangeInCost') :
        raise ValueError ('''termCrit has to be either 
                          'ChangeInW' or 'ChangeInCost' ''')
    
    
    ## In the MATLAB script, had N,T,K, but python shape 
    ## ## function returns in (depth, rows, columns) form, not 
    ## ## rows, columns, deep form. Rotate to compensate
    K,N,T = X.shape

#     W = np.random.rand(K,N,N)
    W = np.zeros(shape=(K,N,N))
    for k in range(K) :
        W[k,:,:] = np.identity(N) 
    
    ## Initializing variables
    cost = np.array([np.NaN for x in range(maxIter)])
    Y = X * 0.0
    
    ## Main Loop
#     for iteration in range(maxIter) :
    for iteration in range(maxIter) :
        termCriterion = 0
        
        ## Initial approximation to true source vectors
        for i in range(K) :
            Y[i,:,:] = np.dot(W[i,:,:], X[i,:,:])
        
        
        ## Initializing values for the iteration summing over datasets, left with N x T
        ## dataset.
        sqrtYtY = np.sqrt(np.sum(Y*Y,0))
        sqrtYtYInv = 1 / sqrtYtY
        
        ## Save current W as W_old
        W_old = W.copy()
        dW    = W*0
        
        ## Computing change in W
        for k in range(K) :
            phi = sqrtYtYInv * Y[k,:,:]
            dW[k,:,:] = W[k,:,:] - np.dot( np.dot(phi, np.transpose(Y[k,:,:]) / T), W[k,:,:])
        
        ## Updating W
        W = W + alpha0 * dW
        
        ## Computing costs
        cost[iteration] = 0
        for k in range(K) :
            cost[iteration] = cost[iteration] + np.log(abs(np.linalg.det(W[k,:,:])))
        
        cost[iteration] = np.sum(np.sum(sqrtYtY)) / T - cost[iteration]
        cost[iteration] = cost[iteration] / (N*K)
        
        ## Check termination Criterion
        if termCrit == 'ChangeInW' :
            for k in range(K) :
                tmp_W = W_old[k,:,:] - W[k,:,:]
                termCriterion = max(termCriterion, np.linalg.norm(tmp_W[:,:]))
                
                ## Old criterion, updated.
#                 termCriterion = max(termCriterion, max(1-np.abs(np.diag(np.dot(W_old[k,:,:], W[k,:,:].T)))))
                
        elif termCrit == 'ChangeInCost' :
            if iteration == 1 :
                termCriterion = 1
                
            else :
                termCriterion = (abs(cost[iteration-1]-cost[iteration])
                                 / abs(cost[iteration]))
        
        
        ## Check termination condition
        if termCriterion < termThreshold or iteration == maxIter :
            break
        elif np.isinf(cost[iteration]) :
            if verbose :
                print "W blew up, restarting with new initial value"
                print "For reference, Here is W."
                print W
                
            
            for i in range(K) :
                W[i,:,:] = np.identity(N) + 0.1 * np.random.rand(N)
            
        elif iteration > 1 and cost[iteration] > cost[iteration-1] :
            alpha0 = max(alphaMin, alphaScale * alpha0)
            print "Changing the alpha0"
            print alpha0
        
        ## Display iteration information
        if verbose :
            print "Step: %i \t W change: %f \t Cost %f" % (iteration, termCriterion, cost[iteration])
        
        ## End iteration
    
    ## Finish display
    if verbose :
        print "Algorithim converged, end results are: "
        print " Step: %i \n W change: %f \n Cost %f \n\n" % (iteration, termCriterion, cost[iteration])
        
    return W

# %%
def vecnorm(A) :
    ''' 
    Takes a matrix of vectors and produces a matrix with the same span,
        but with every vector normalized.
        
    Inputs:
    ------------------------------------------------------------------------------
    A = matrix of vectors. A must be a D x N matrix, cannot be multidimensional.
    
    Outputs:
    ------------------------------------------------------------------------------
    A = D x N matrix of vectors. note that every column vector in A has the same 
        span as every corresponding column vector in B.
        
    '''
    
    N = A.shape[1]
    
    
    for n in range(N) :
        A[:,n] = A[:,n] / np.sqrt(np.sum(A[:,n] * A[:,n], axis=0))
    
    return A

# %%
def test_IVA_L ( ) :
    '''
    Takes no inputs, prints sourec vectors, unmxing matrix, what the 
        true unmixing matrix should look like, and what the unmixing 
        matrix that IVA_L returned looks like
    '''
    
    
    print "Running test_IVA_L function"
    
    N=3
    K=10
    T=10000
    
    ## We are currently, in an attempt to compare matlab and python code
    ## for errors, controlling S and A, but otherwise, this is the right 
    ## code.
#     S = np.zeros(shape=(K,N,T))
    
#     for n in range(N) :
#         Z = mvl.randmv_laplace(K,T)
#         S[:,n,:] = Z
        
#     A = np.random.rand(K,N,N)
#     X = s.copy()
    
    A = np.zeros(shape=(10,3,3))

    A = a['A']
    S = a['S']
    A_py = np.zeros(shape=(10,3,3))
    S_py = np.zeros(shape=(10,3,10000))
    
    for i in range(3) :
        for k in range(10) :
            for j in range(3) :
                A_py[k,i,j] = A[i,j,k]
            for j in range(10000) :
                S_py[k,i,j] = S[i,j,k]

    X = S_py.copy()
    
    for k in range(K) :
#         A[k,:,:] = np.transpose(vecnorm(A[k,:,:]))
        X[k,:,:] = np.dot(A_py[k,:,:], S_py[k,:,:])
        
#     print "The source vectors S are \n", S, "\n\n"
#     print "The mixing matrix A is \n", A, "\n\n"
    
#     for k in range(K) :
#         print "The true unmixing matrix W for site %i is \n" % k, np.linalg.pinv(A_py[k,:,:]), "\n"
    
    
    W = IVA_L (X, verbose=True)

    print "IVA_L found that the unmixing matrix W is \n", W, "\n\n"
    
    for k in range(K) :
        print "For site %i, the unmixing matrix W times A is \n" % k

        print np.dot(W[k,:,:], A_py[k,:,:]), "\n"
        
#     for k in range(K) :
#         print "For site %i, IVA_L found that the true source vectors are \n" % k
        
#         print np.dot(W[k,:,:], X[k,:,:])

# %%
if __name__ == "__main__" :
    print test_IVA_L ()
# Out:
# Running test_IVA_L function
# Step: 0 	 W change: nan 	 Cost 0.493382
# Step: 1 	 W change: 1.000000 	 Cost 0.424961
# Step: 2 	 W change: 0.154381 	 Cost 0.368129
# Step: 3 	 W change: 0.159631 	 Cost 0.317453
# Step: 4 	 W change: 0.171879 	 Cost 0.270893
# Step: 5 	 W change: 0.191203 	 Cost 0.227411
# Step: 6 	 W change: 0.219952 	 Cost 0.186410
# Step: 7 	 W change: 0.263633 	 Cost 0.147519
# Step: 8 	 W change: 0.334978 	 Cost 0.110503
# Step: 9 	 W change: 0.469220 	 Cost 0.075212
# Step: 10 	 W change: 0.809970 	 Cost 0.041554
# Step: 11 	 W change: 3.384368 	 Cost 0.009478
# Step: 12 	 W change: 1.450424 	 Cost -0.021042
# Step: 13 	 W change: 0.579264 	 Cost -0.050012
# Step: 14 	 W change: 0.354106 	 Cost -0.077431
# Step: 15 	 W change: 0.250381 	 Cost -0.103294
# Step: 16 	 W change: 0.190487 	 Cost -0.127601
# Step: 17 	 W change: 0.151354 	 Cost -0.150358
# Step: 18 	 W change: 0.123716 	 Cost -0.171586
# Step: 19 	 W change: 0.103139 	 Cost -0.191318
# Step: 20 	 W change: 0.087236 	 Cost -0.209603
# Step: 21 	 W change: 0.074609 	 Cost -0.226502
# Step: 22 	 W change: 0.064384 	 Cost -0.242089
# Step: 23 	 W change: 0.055980 	 Cost -0.256444
# Step: 24 	 W change: 0.048999 	 Cost -0.269658
# Step: 25 	 W change: 0.043152 	 Cost -0.281818
# Step: 26 	 W change: 0.038222 	 Cost -0.293018
# Step: 27 	 W change: 0.034048 	 Cost -0.303347
# Step: 28 	 W change: 0.030500 	 Cost -0.312890
# Step: 29 	 W change: 0.027475 	 Cost -0.321729
# Step: 30 	 W change: 0.024890 	 Cost -0.329941
# Step: 31 	 W change: 0.022676 	 Cost -0.337597
# Step: 32 	 W change: 0.020773 	 Cost -0.344758
# Step: 33 	 W change: 0.019129 	 Cost -0.351482
# Step: 34 	 W change: 0.017699 	 Cost -0.357815
# Step: 35 	 W change: 0.016442 	 Cost -0.363796
# Step: 36 	 W change: 0.015324 	 Cost -0.369458
# Step: 37 	 W change: 0.014315 	 Cost -0.374823
# Step: 38 	 W change: 0.013388 	 Cost -0.379910
# Step: 39 	 W change: 0.012525 	 Cost -0.384729
# Step: 40 	 W change: 0.011710 	 Cost -0.389287
# Step: 41 	 W change: 0.010931 	 Cost -0.393589
# Step: 42 	 W change: 0.010182 	 Cost -0.397638
# Step: 43 	 W change: 0.009458 	 Cost -0.401435
# Step: 44 	 W change: 0.008757 	 Cost -0.404981
# Step: 45 	 W change: 0.008079 	 Cost -0.408280
# Step: 46 	 W change: 0.007423 	 Cost -0.411333
# Step: 47 	 W change: 0.006788 	 Cost -0.414144
# Step: 48 	 W change: 0.006175 	 Cost -0.416718
# Step: 49 	 W change: 0.005582 	 Cost -0.419057
# Step: 50 	 W change: 0.005008 	 Cost -0.421166
# Step: 51 	 W change: 0.004452 	 Cost -0.423049
# Step: 52 	 W change: 0.003914 	 Cost -0.424711
# Step: 53 	 W change: 0.003395 	 Cost -0.426158
# Step: 54 	 W change: 0.002899 	 Cost -0.427397
# Step: 55 	 W change: 0.002430 	 Cost -0.428438
# Step: 56 	 W change: 0.001993 	 Cost -0.429294
# Step: 57 	 W change: 0.001593 	 Cost -0.429979
# Step: 58 	 W change: 0.001237 	 Cost -0.430511
# Step: 59 	 W change: 0.000926 	 Cost -0.430911
# Step: 60 	 W change: 0.000664 	 Cost -0.431197
# Step: 61 	 W change: 0.000449 	 Cost -0.431391
# Step: 62 	 W change: 0.000279 	 Cost -0.431511
# Step: 63 	 W change: 0.000149 	 Cost -0.431575
# Step: 64 	 W change: 0.000053 	 Cost -0.431598
# Changing the alpha0
# 0.1
# Step: 65 	 W change: 0.000013 	 Cost -0.431592
# Changing the alpha0
# 0.1
# Step: 66 	 W change: 0.000056 	 Cost -0.431568
# Changing the alpha0
# 0.1
# Step: 67 	 W change: 0.000081 	 Cost -0.431533
# Changing the alpha0
# 0.1
# Step: 68 	 W change: 0.000092 	 Cost -0.431493
# Changing the alpha0
# 0.1
# Step: 69 	 W change: 0.000094 	 Cost -0.431453
# Changing the alpha0
# 0.1
# Step: 70 	 W change: 0.000089 	 Cost -0.431414
# Changing the alpha0
# 0.1
# Step: 71 	 W change: 0.000080 	 Cost -0.431380
# Changing the alpha0
# 0.1
# Step: 72 	 W change: 0.000068 	 Cost -0.431350
# Changing the alpha0
# 0.1
# Step: 73 	 W change: 0.000054 	 Cost -0.431327
# Changing the alpha0
# 0.1
# Step: 74 	 W change: 0.000040 	 Cost -0.431310
# Changing the alpha0
# 0.1
# Step: 75 	 W change: 0.000025 	 Cost -0.431299
# Changing the alpha0
# 0.1
# Step: 76 	 W change: 0.000011 	 Cost -0.431294
# Step: 77 	 W change: 0.000003 	 Cost -0.431296
# Step: 78 	 W change: 0.000017 	 Cost -0.431303
# Step: 79 	 W change: 0.000030 	 Cost -0.431316
# Step: 80 	 W change: 0.000042 	 Cost -0.431334
# Step: 81 	 W change: 0.000053 	 Cost -0.431357
# Step: 82 	 W change: 0.000064 	 Cost -0.431384
# Step: 83 	 W change: 0.000074 	 Cost -0.431416
# Step: 84 	 W change: 0.000083 	 Cost -0.431452
# Step: 85 	 W change: 0.000092 	 Cost -0.431492
# Step: 86 	 W change: 0.000101 	 Cost -0.431535
# Step: 87 	 W change: 0.000109 	 Cost -0.431582
# Step: 88 	 W change: 0.000116 	 Cost -0.431632
# Step: 89 	 W change: 0.000123 	 Cost -0.431686
# Step: 90 	 W change: 0.000130 	 Cost -0.431742
# Step: 91 	 W change: 0.000137 	 Cost -0.431801
# Step: 92 	 W change: 0.000143 	 Cost -0.431863
# Step: 93 	 W change: 0.000150 	 Cost -0.431928
# Step: 94 	 W change: 0.000156 	 Cost -0.431995
# Step: 95 	 W change: 0.000161 	 Cost -0.432065
# Step: 96 	 W change: 0.000167 	 Cost -0.432137
# Step: 97 	 W change: 0.000173 	 Cost -0.432212
# Step: 98 	 W change: 0.000178 	 Cost -0.432289
# Step: 99 	 W change: 0.000184 	 Cost -0.432368
# Step: 100 	 W change: 0.000189 	 Cost -0.432450
# Step: 101 	 W change: 0.000194 	 Cost -0.432534
# Step: 102 	 W change: 0.000200 	 Cost -0.432620
# Step: 103 	 W change: 0.000205 	 Cost -0.432709
# Step: 104 	 W change: 0.000210 	 Cost -0.432800
# Step: 105 	 W change: 0.000215 	 Cost -0.432893
# Step: 106 	 W change: 0.000221 	 Cost -0.432988
# Step: 107 	 W change: 0.000226 	 Cost -0.433086
# Step: 108 	 W change: 0.000231 	 Cost -0.433186
# Step: 109 	 W change: 0.000236 	 Cost -0.433289
# Step: 110 	 W change: 0.000242 	 Cost -0.433394
# Step: 111 	 W change: 0.000247 	 Cost -0.433501
# Step: 112 	 W change: 0.000253 	 Cost -0.433610
# Step: 113 	 W change: 0.000258 	 Cost -0.433722
# Step: 114 	 W change: 0.000264 	 Cost -0.433837
# Step: 115 	 W change: 0.000269 	 Cost -0.433953
# Step: 116 	 W change: 0.000275 	 Cost -0.434073
# Step: 117 	 W change: 0.000280 	 Cost -0.434194
# Step: 118 	 W change: 0.000286 	 Cost -0.434319
# Step: 119 	 W change: 0.000292 	 Cost -0.434446
# Step: 120 	 W change: 0.000298 	 Cost -0.434575
# Step: 121 	 W change: 0.000303 	 Cost -0.434707
# Step: 122 	 W change: 0.000309 	 Cost -0.434841
# Step: 123 	 W change: 0.000315 	 Cost -0.434978
# Step: 124 	 W change: 0.000321 	 Cost -0.435118
# Step: 125 	 W change: 0.000327 	 Cost -0.435260
# Step: 126 	 W change: 0.000333 	 Cost -0.435405
# Step: 127 	 W change: 0.000339 	 Cost -0.435553
# Step: 128 	 W change: 0.000345 	 Cost -0.435703
# Step: 129 	 W change: 0.000351 	 Cost -0.435856
# Step: 130 	 W change: 0.000357 	 Cost -0.436012
# Step: 131 	 W change: 0.000363 	 Cost -0.436170
# Step: 132 	 W change: 0.000369 	 Cost -0.436331
# Step: 133 	 W change: 0.000374 	 Cost -0.436494
# Step: 134 	 W change: 0.000380 	 Cost -0.436660
# Step: 135 	 W change: 0.000386 	 Cost -0.436829
# Step: 136 	 W change: 0.000392 	 Cost -0.437000
# Step: 137 	 W change: 0.000398 	 Cost -0.437174
# Step: 138 	 W change: 0.000403 	 Cost -0.437350
# Step: 139 	 W change: 0.000409 	 Cost -0.437529
# Step: 140 	 W change: 0.000414 	 Cost -0.437710
# Step: 141 	 W change: 0.000420 	 Cost -0.437894
# Step: 142 	 W change: 0.000425 	 Cost -0.438080
# Step: 143 	 W change: 0.000430 	 Cost -0.438269
# Step: 144 	 W change: 0.000435 	 Cost -0.438459
# Step: 145 	 W change: 0.000440 	 Cost -0.438652
# Step: 146 	 W change: 0.000445 	 Cost -0.438848
# Step: 147 	 W change: 0.000449 	 Cost -0.439045
# Step: 148 	 W change: 0.000454 	 Cost -0.439244
# Step: 149 	 W change: 0.000458 	 Cost -0.439446
# Step: 150 	 W change: 0.000462 	 Cost -0.439649
# Step: 151 	 W change: 0.000466 	 Cost -0.439854
# Step: 152 	 W change: 0.000470 	 Cost -0.440061
# Step: 153 	 W change: 0.000474 	 Cost -0.440270
# Step: 154 	 W change: 0.000477 	 Cost -0.440480
# Step: 155 	 W change: 0.000481 	 Cost -0.440692
# Step: 156 	 W change: 0.000484 	 Cost -0.440905
# Step: 157 	 W change: 0.000487 	 Cost -0.441120
# Step: 158 	 W change: 0.000490 	 Cost -0.441336
# Step: 159 	 W change: 0.000492 	 Cost -0.441554
# Step: 160 	 W change: 0.000495 	 Cost -0.441772
# Step: 161 	 W change: 0.000497 	 Cost -0.441992
# Step: 162 	 W change: 0.000499 	 Cost -0.442213
# Step: 163 	 W change: 0.000501 	 Cost -0.442434
# Step: 164 	 W change: 0.000503 	 Cost -0.442657
# Step: 165 	 W change: 0.000504 	 Cost -0.442880
# Step: 166 	 W change: 0.000506 	 Cost -0.443104
# Step: 167 	 W change: 0.000507 	 Cost -0.443329
# Step: 168 	 W change: 0.000508 	 Cost -0.443555
# Step: 169 	 W change: 0.000509 	 Cost -0.443781
# Step: 170 	 W change: 0.000510 	 Cost -0.444007
# Step: 171 	 W change: 0.000511 	 Cost -0.444234
# Step: 172 	 W change: 0.000512 	 Cost -0.444462
# Step: 173 	 W change: 0.000512 	 Cost -0.444689
# Step: 174 	 W change: 0.000513 	 Cost -0.444918
# Step: 175 	 W change: 0.000513 	 Cost -0.445146
# Step: 176 	 W change: 0.000513 	 Cost -0.445375
# Step: 177 	 W change: 0.000514 	 Cost -0.445604
# Step: 178 	 W change: 0.000514 	 Cost -0.445833
# Step: 179 	 W change: 0.000514 	 Cost -0.446062
# Step: 180 	 W change: 0.000514 	 Cost -0.446291
# Step: 181 	 W change: 0.000514 	 Cost -0.446521
# Step: 182 	 W change: 0.000514 	 Cost -0.446750
# Step: 183 	 W change: 0.000513 	 Cost -0.446980
# Step: 184 	 W change: 0.000513 	 Cost -0.447209
# Step: 185 	 W change: 0.000513 	 Cost -0.447439
# Step: 186 	 W change: 0.000512 	 Cost -0.447668
# Step: 187 	 W change: 0.000512 	 Cost -0.447897
# Step: 188 	 W change: 0.000511 	 Cost -0.448126
# Step: 189 	 W change: 0.000511 	 Cost -0.448355
# Step: 190 	 W change: 0.000510 	 Cost -0.448584
# Step: 191 	 W change: 0.000509 	 Cost -0.448813
# Step: 192 	 W change: 0.000508 	 Cost -0.449041
# Step: 193 	 W change: 0.000507 	 Cost -0.449268
# Step: 194 	 W change: 0.000506 	 Cost -0.449496
# Step: 195 	 W change: 0.000504 	 Cost -0.449723
# Step: 196 	 W change: 0.000503 	 Cost -0.449949
# Step: 197 	 W change: 0.000501 	 Cost -0.450174
# Step: 198 	 W change: 0.000499 	 Cost -0.450399
# Step: 199 	 W change: 0.000497 	 Cost -0.450623
# Step: 200 	 W change: 0.000495 	 Cost -0.450846
# Step: 201 	 W change: 0.000492 	 Cost -0.451068
# Step: 202 	 W change: 0.000489 	 Cost -0.451289
# Step: 203 	 W change: 0.000486 	 Cost -0.451508
# Step: 204 	 W change: 0.000483 	 Cost -0.451727
# Step: 205 	 W change: 0.000480 	 Cost -0.451943
# Step: 206 	 W change: 0.000476 	 Cost -0.452158
# Step: 207 	 W change: 0.000472 	 Cost -0.452372
# Step: 208 	 W change: 0.000467 	 Cost -0.452583
# Step: 209 	 W change: 0.000463 	 Cost -0.452793
# Step: 210 	 W change: 0.000458 	 Cost -0.453000
# Step: 211 	 W change: 0.000453 	 Cost -0.453205
# Step: 212 	 W change: 0.000447 	 Cost -0.453408
# Step: 213 	 W change: 0.000441 	 Cost -0.453608
# Step: 214 	 W change: 0.000435 	 Cost -0.453805
# Step: 215 	 W change: 0.000429 	 Cost -0.454000
# Step: 216 	 W change: 0.000422 	 Cost -0.454192
# Step: 217 	 W change: 0.000415 	 Cost -0.454380
# Step: 218 	 W change: 0.000408 	 Cost -0.454566
# Step: 219 	 W change: 0.000400 	 Cost -0.454748
# Step: 220 	 W change: 0.000393 	 Cost -0.454926
# Step: 221 	 W change: 0.000385 	 Cost -0.455101
# Step: 222 	 W change: 0.000376 	 Cost -0.455273
# Step: 223 	 W change: 0.000368 	 Cost -0.455440
# Step: 224 	 W change: 0.000360 	 Cost -0.455604
# Step: 225 	 W change: 0.000351 	 Cost -0.455764
# Step: 226 	 W change: 0.000342 	 Cost -0.455920
# Step: 227 	 W change: 0.000334 	 Cost -0.456072
# Step: 228 	 W change: 0.000325 	 Cost -0.456221
# Step: 229 	 W change: 0.000316 	 Cost -0.456365
# Step: 230 	 W change: 0.000308 	 Cost -0.456505
# Step: 231 	 W change: 0.000299 	 Cost -0.456642
# Step: 232 	 W change: 0.000291 	 Cost -0.456775
# Step: 233 	 W change: 0.000283 	 Cost -0.456904
# Step: 234 	 W change: 0.000275 	 Cost -0.457029
# Step: 235 	 W change: 0.000267 	 Cost -0.457151
# Step: 236 	 W change: 0.000259 	 Cost -0.457270
# Step: 237 	 W change: 0.000252 	 Cost -0.457386
# Step: 238 	 W change: 0.000246 	 Cost -0.457498
# Step: 239 	 W change: 0.000239 	 Cost -0.457608
# Step: 240 	 W change: 0.000234 	 Cost -0.457714
# Step: 241 	 W change: 0.000228 	 Cost -0.457819
# Step: 242 	 W change: 0.000223 	 Cost -0.457921
# Step: 243 	 W change: 0.000219 	 Cost -0.458021
# Step: 244 	 W change: 0.000215 	 Cost -0.458120
# Step: 245 	 W change: 0.000211 	 Cost -0.458217
# Step: 246 	 W change: 0.000208 	 Cost -0.458312
# Step: 247 	 W change: 0.000206 	 Cost -0.458407
# Step: 248 	 W change: 0.000204 	 Cost -0.458500
# Step: 249 	 W change: 0.000203 	 Cost -0.458593
# Step: 250 	 W change: 0.000202 	 Cost -0.458686
# Step: 251 	 W change: 0.000202 	 Cost -0.458778
# Step: 252 	 W change: 0.000202 	 Cost -0.458871
# Step: 253 	 W change: 0.000202 	 Cost -0.458964
# Step: 254 	 W change: 0.000204 	 Cost -0.459057
# Step: 255 	 W change: 0.000205 	 Cost -0.459151
# Step: 256 	 W change: 0.000207 	 Cost -0.459247
# Step: 257 	 W change: 0.000210 	 Cost -0.459343
# Step: 258 	 W change: 0.000213 	 Cost -0.459441
# Step: 259 	 W change: 0.000217 	 Cost -0.459541
# Step: 260 	 W change: 0.000221 	 Cost -0.459642
# Step: 261 	 W change: 0.000225 	 Cost -0.459746
# Step: 262 	 W change: 0.000230 	 Cost -0.459852
# Step: 263 	 W change: 0.000235 	 Cost -0.459960
# Step: 264 	 W change: 0.000241 	 Cost -0.460071
# Step: 265 	 W change: 0.000247 	 Cost -0.460185
# Step: 266 	 W change: 0.000254 	 Cost -0.460301
# Step: 267 	 W change: 0.000261 	 Cost -0.460421
# Step: 268 	 W change: 0.000268 	 Cost -0.460545
# Step: 269 	 W change: 0.000276 	 Cost -0.460671
# Step: 270 	 W change: 0.000284 	 Cost -0.460802
# Step: 271 	 W change: 0.000292 	 Cost -0.460937
# Step: 272 	 W change: 0.000301 	 Cost -0.461075
# Step: 273 	 W change: 0.000310 	 Cost -0.461218
# Step: 274 	 W change: 0.000320 	 Cost -0.461366
# Step: 275 	 W change: 0.000329 	 Cost -0.461518
# Step: 276 	 W change: 0.000340 	 Cost -0.461675
# Step: 277 	 W change: 0.000350 	 Cost -0.461836
# Step: 278 	 W change: 0.000361 	 Cost -0.462003
# Step: 279 	 W change: 0.000372 	 Cost -0.462176
# Step: 280 	 W change: 0.000384 	 Cost -0.462353
# Step: 281 	 W change: 0.000396 	 Cost -0.462536
# Step: 282 	 W change: 0.000408 	 Cost -0.462725
# Step: 283 	 W change: 0.000421 	 Cost -0.462920
# Step: 284 	 W change: 0.000433 	 Cost -0.463121
# Step: 285 	 W change: 0.000446 	 Cost -0.463327
# Step: 286 	 W change: 0.000460 	 Cost -0.463541
# Step: 287 	 W change: 0.000473 	 Cost -0.463760
# Step: 288 	 W change: 0.000487 	 Cost -0.463986
# Step: 289 	 W change: 0.000501 	 Cost -0.464218
# Step: 290 	 W change: 0.000514 	 Cost -0.464457
# Step: 291 	 W change: 0.000528 	 Cost -0.464703
# Step: 292 	 W change: 0.000543 	 Cost -0.464955
# Step: 293 	 W change: 0.000557 	 Cost -0.465214
# Step: 294 	 W change: 0.000571 	 Cost -0.465480
# Step: 295 	 W change: 0.000585 	 Cost -0.465752
# Step: 296 	 W change: 0.000599 	 Cost -0.466031
# Step: 297 	 W change: 0.000612 	 Cost -0.466316
# Step: 298 	 W change: 0.000626 	 Cost -0.466608
# Step: 299 	 W change: 0.000639 	 Cost -0.466906
# Step: 300 	 W change: 0.000652 	 Cost -0.467211
# Step: 301 	 W change: 0.000664 	 Cost -0.467521
# Step: 302 	 W change: 0.000676 	 Cost -0.467838
# Step: 303 	 W change: 0.000687 	 Cost -0.468159
# Step: 304 	 W change: 0.000698 	 Cost -0.468486
# Step: 305 	 W change: 0.000708 	 Cost -0.468818
# Step: 306 	 W change: 0.000718 	 Cost -0.469155
# Step: 307 	 W change: 0.000726 	 Cost -0.469496
# Step: 308 	 W change: 0.000734 	 Cost -0.469841
# Step: 309 	 W change: 0.000740 	 Cost -0.470189
# Step: 310 	 W change: 0.000746 	 Cost -0.470540
# Step: 311 	 W change: 0.000751 	 Cost -0.470893
# Step: 312 	 W change: 0.000755 	 Cost -0.471249
# Step: 313 	 W change: 0.000757 	 Cost -0.471606
# Step: 314 	 W change: 0.000758 	 Cost -0.471964
# Step: 315 	 W change: 0.000759 	 Cost -0.472322
# Step: 316 	 W change: 0.000758 	 Cost -0.472681
# Step: 317 	 W change: 0.000756 	 Cost -0.473038
# Step: 318 	 W change: 0.000752 	 Cost -0.473394
# Step: 319 	 W change: 0.000748 	 Cost -0.473749
# Step: 320 	 W change: 0.000742 	 Cost -0.474101
# Step: 321 	 W change: 0.000736 	 Cost -0.474450
# Step: 322 	 W change: 0.000728 	 Cost -0.474796
# Step: 323 	 W change: 0.000720 	 Cost -0.475138
# Step: 324 	 W change: 0.000710 	 Cost -0.475475
# Step: 325 	 W change: 0.000700 	 Cost -0.475808
# Step: 326 	 W change: 0.000688 	 Cost -0.476136
# Step: 327 	 W change: 0.000677 	 Cost -0.476458
# Step: 328 	 W change: 0.000664 	 Cost -0.476775
# Step: 329 	 W change: 0.000651 	 Cost -0.477085
# Step: 330 	 W change: 0.000637 	 Cost -0.477389
# Step: 331 	 W change: 0.000623 	 Cost -0.477687
# Step: 332 	 W change: 0.000608 	 Cost -0.477978
# Step: 333 	 W change: 0.000593 	 Cost -0.478262
# Step: 334 	 W change: 0.000578 	 Cost -0.478538
# Step: 335 	 W change: 0.000563 	 Cost -0.478808
# Step: 336 	 W change: 0.000547 	 Cost -0.479070
# Step: 337 	 W change: 0.000531 	 Cost -0.479325
# Step: 338 	 W change: 0.000516 	 Cost -0.479572
# Step: 339 	 W change: 0.000499 	 Cost -0.479812
# Step: 340 	 W change: 0.000483 	 Cost -0.480044
# Step: 341 	 W change: 0.000467 	 Cost -0.480268
# Step: 342 	 W change: 0.000451 	 Cost -0.480485
# Step: 343 	 W change: 0.000435 	 Cost -0.480694
# Step: 344 	 W change: 0.000419 	 Cost -0.480896
# Step: 345 	 W change: 0.000404 	 Cost -0.481090
# Step: 346 	 W change: 0.000388 	 Cost -0.481277
# Step: 347 	 W change: 0.000373 	 Cost -0.481456
# Step: 348 	 W change: 0.000358 	 Cost -0.481629
# Step: 349 	 W change: 0.000344 	 Cost -0.481794
# Step: 350 	 W change: 0.000330 	 Cost -0.481953
# Step: 351 	 W change: 0.000317 	 Cost -0.482106
# Step: 352 	 W change: 0.000305 	 Cost -0.482253
# Step: 353 	 W change: 0.000293 	 Cost -0.482395
# Step: 354 	 W change: 0.000282 	 Cost -0.482531
# Step: 355 	 W change: 0.000273 	 Cost -0.482662
# Step: 356 	 W change: 0.000264 	 Cost -0.482790
# Step: 357 	 W change: 0.000256 	 Cost -0.482913
# Step: 358 	 W change: 0.000249 	 Cost -0.483034
# Step: 359 	 W change: 0.000243 	 Cost -0.483151
# Step: 360 	 W change: 0.000239 	 Cost -0.483267
# Step: 361 	 W change: 0.000235 	 Cost -0.483380
# Step: 362 	 W change: 0.000233 	 Cost -0.483493
# Step: 363 	 W change: 0.000232 	 Cost -0.483605
# Step: 364 	 W change: 0.000231 	 Cost -0.483717
# Step: 365 	 W change: 0.000232 	 Cost -0.483829
# Step: 366 	 W change: 0.000234 	 Cost -0.483943
# Step: 367 	 W change: 0.000237 	 Cost -0.484057
# Step: 368 	 W change: 0.000241 	 Cost -0.484174
# Step: 369 	 W change: 0.000246 	 Cost -0.484294
# Step: 370 	 W change: 0.000253 	 Cost -0.484416
# Step: 371 	 W change: 0.000260 	 Cost -0.484542
# Step: 372 	 W change: 0.000268 	 Cost -0.484671
# Step: 373 	 W change: 0.000277 	 Cost -0.484806
# Step: 374 	 W change: 0.000286 	 Cost -0.484944
# Step: 375 	 W change: 0.000297 	 Cost -0.485089
# Step: 376 	 W change: 0.000309 	 Cost -0.485238
# Step: 377 	 W change: 0.000321 	 Cost -0.485394
# Step: 378 	 W change: 0.000335 	 Cost -0.485557
# Step: 379 	 W change: 0.000349 	 Cost -0.485727
# Step: 380 	 W change: 0.000364 	 Cost -0.485904
# Step: 381 	 W change: 0.000380 	 Cost -0.486089
# Step: 382 	 W change: 0.000397 	 Cost -0.486282
# Step: 383 	 W change: 0.000415 	 Cost -0.486483
# Step: 384 	 W change: 0.000433 	 Cost -0.486694
# Step: 385 	 W change: 0.000452 	 Cost -0.486914
# Step: 386 	 W change: 0.000472 	 Cost -0.487144
# Step: 387 	 W change: 0.000493 	 Cost -0.487385
# Step: 388 	 W change: 0.000514 	 Cost -0.487635
# Step: 389 	 W change: 0.000536 	 Cost -0.487897
# Step: 390 	 W change: 0.000558 	 Cost -0.488169
# Step: 391 	 W change: 0.000581 	 Cost -0.488453
# Step: 392 	 W change: 0.000604 	 Cost -0.488749
# Step: 393 	 W change: 0.000628 	 Cost -0.489056
# Step: 394 	 W change: 0.000651 	 Cost -0.489374
# Step: 395 	 W change: 0.000675 	 Cost -0.489705
# Step: 396 	 W change: 0.000698 	 Cost -0.490047
# Step: 397 	 W change: 0.000721 	 Cost -0.490401
# Step: 398 	 W change: 0.000744 	 Cost -0.490766
# Step: 399 	 W change: 0.000765 	 Cost -0.491141
# Step: 400 	 W change: 0.000786 	 Cost -0.491527
# Step: 401 	 W change: 0.000805 	 Cost -0.491923
# Step: 402 	 W change: 0.000822 	 Cost -0.492328
# Step: 403 	 W change: 0.000838 	 Cost -0.492741
# Step: 404 	 W change: 0.000851 	 Cost -0.493161
# Step: 405 	 W change: 0.000862 	 Cost -0.493587
# Step: 406 	 W change: 0.000870 	 Cost -0.494017
# Step: 407 	 W change: 0.000875 	 Cost -0.494449
# Step: 408 	 W change: 0.000877 	 Cost -0.494883
# Step: 409 	 W change: 0.000875 	 Cost -0.495317
# Step: 410 	 W change: 0.000869 	 Cost -0.495747
# Step: 411 	 W change: 0.000859 	 Cost -0.496173
# Step: 412 	 W change: 0.000845 	 Cost -0.496593
# Step: 413 	 W change: 0.000826 	 Cost -0.497003
# Step: 414 	 W change: 0.000804 	 Cost -0.497403
# Step: 415 	 W change: 0.000777 	 Cost -0.497790
# Step: 416 	 W change: 0.000747 	 Cost -0.498162
# Step: 417 	 W change: 0.000713 	 Cost -0.498518
# Step: 418 	 W change: 0.000676 	 Cost -0.498855
# Step: 419 	 W change: 0.000637 	 Cost -0.499173
# Step: 420 	 W change: 0.000595 	 Cost -0.499470
# Step: 421 	 W change: 0.000552 	 Cost -0.499746
# Step: 422 	 W change: 0.000508 	 Cost -0.500000
# Step: 423 	 W change: 0.000464 	 Cost -0.500233
# Step: 424 	 W change: 0.000421 	 Cost -0.500443
# Step: 425 	 W change: 0.000378 	 Cost -0.500633
# Step: 426 	 W change: 0.000337 	 Cost -0.500802
# Step: 427 	 W change: 0.000298 	 Cost -0.500951
# Step: 428 	 W change: 0.000262 	 Cost -0.501082
# Step: 429 	 W change: 0.000228 	 Cost -0.501196
# Step: 430 	 W change: 0.000196 	 Cost -0.501295
# Step: 431 	 W change: 0.000168 	 Cost -0.501379
# Step: 432 	 W change: 0.000142 	 Cost -0.501450
# Step: 433 	 W change: 0.000120 	 Cost -0.501510
# Step: 434 	 W change: 0.000100 	 Cost -0.501560
# Step: 435 	 W change: 0.000082 	 Cost -0.501602
# Step: 436 	 W change: 0.000067 	 Cost -0.501636
# Step: 437 	 W change: 0.000055 	 Cost -0.501663
# Step: 438 	 W change: 0.000044 	 Cost -0.501685
# Step: 439 	 W change: 0.000035 	 Cost -0.501702
# Step: 440 	 W change: 0.000027 	 Cost -0.501716
# Step: 441 	 W change: 0.000021 	 Cost -0.501726
# Step: 442 	 W change: 0.000015 	 Cost -0.501734
# Step: 443 	 W change: 0.000011 	 Cost -0.501739
# Step: 444 	 W change: 0.000008 	 Cost -0.501743
# Step: 445 	 W change: 0.000005 	 Cost -0.501746
# Step: 446 	 W change: 0.000003 	 Cost -0.501747
# Step: 447 	 W change: 0.000001 	 Cost -0.501748
# Algorithim converged, end results are:
#  Step: 448
#  W change: 0.000000
#  Cost -0.501748
#
#
# IVA_L found that the unmixing matrix W is
# [[[  5.55797068e+00  -4.09835309e+00   4.13691712e+00]
#   [  3.73123734e+00   4.20334792e-01   2.29021615e+00]
#   [ -3.01368916e+00   2.68162430e-01   2.44115763e-02]]
#
#  [[  6.68343491e-01   4.89947377e-01   2.24444015e+00]
#   [ -3.55886605e+00   7.16445632e+00   2.26711559e+00]
#   [ -1.32423756e+00  -3.83111075e+00   5.66770165e-01]]
#
#  [[  1.71003705e+00  -1.90584186e+00   4.79964136e-01]
#   [ -1.92301015e+00   9.68147963e+00   4.33253128e-01]
#   [  1.26809786e+00  -1.63769761e+00   1.97981710e+00]]
#
#  [[  1.53075182e+01   8.38661087e+00   6.03723488e-01]
#   [  4.88830181e+00   4.10138944e+00   1.11429579e+00]
#   [  9.45556326e-01  -7.77395200e-01   6.72032057e-01]]
#
#  [[ -5.02869134e-01   3.33249547e-01   4.47482866e+00]
#   [  1.30447203e+00   1.16423342e+00  -5.21849952e+00]
#   [ -5.00761924e+00   2.42108818e+00   5.28021602e+00]]
#
#  [[  1.76328777e+00  -8.36436988e+01  -2.64634592e+01]
#   [ -3.18650805e+00   1.76654198e+01  -3.13444535e-01]
#   [  4.67148980e+00   1.11494939e+01   6.47056034e+00]]
#
#  [[ -1.05794678e+02   5.82923495e+01  -9.92918641e+01]
#   [ -1.04659517e+02   5.65895344e+01  -9.62250310e+01]
#   [  7.96595601e+01  -4.12121064e+01   7.62550511e+01]]
#
#  [[ -2.00817728e+00   2.69259430e+00  -7.75938750e+00]
#   [  1.28816862e+01  -4.08844158e+00   5.56999991e+00]
#   [  5.57469344e+00  -8.19630302e+00   8.70343159e+00]]
#
#  [[  4.85895348e+00   3.23064736e+00  -2.27416178e+00]
#   [  4.07639638e+00   4.68796351e+00  -3.84720838e+00]
#   [ -2.95819305e-01   6.58133404e-01   4.05438008e+00]]
#
#  [[  6.02994275e+00   6.60489381e+00  -8.29852518e-01]
#   [  7.78774430e-01   1.85203093e+00  -2.13443911e+00]
#   [  3.23576216e+00   6.12460640e+00  -8.48433065e-01]]]
#
#
# For site 0, the unmixing matrix W times A is
#
# [[  2.19520986e-02   3.65195416e+00  -3.86685035e-02]
#  [  1.58541089e-04  -1.26355909e-02  -3.62311119e+00]
#  [ -3.66625540e+00   2.21877597e-02   4.15508258e-02]]
#
# For site 1, the unmixing matrix W times A is
#
# [[ -3.04899019e-02   3.60271345e+00  -1.32173008e-02]
#  [  9.96487865e-03   1.24518379e-03  -3.60095992e+00]
#  [ -3.64967359e+00  -1.93113941e-02  -4.55475988e-02]]
#
# For site 2, the unmixing matrix W times A is
#
# [[ 0.00713135  3.67086744 -0.03354642]
#  [ 0.02735163  0.03198302  3.67696089]
#  [ 3.61688773  0.01181952 -0.03263227]]
#
# For site 3, the unmixing matrix W times A is
#
# [[  2.64666064e-02   3.63083514e+00  -4.42462299e-02]
#  [ -9.62802233e-03  -6.96749383e-03   3.65044951e+00]
#  [ -3.66710834e+00  -3.03046029e-03   1.07783592e-02]]
#
# For site 4, the unmixing matrix W times A is
#
# [[-0.02748028 -3.66146749 -0.0372196 ]
#  [-0.03549666  0.01405462  3.61733576]
#  [-3.60126296 -0.01224018 -0.01013104]]
#
# For site 5, the unmixing matrix W times A is
#
# [[-0.00497319 -3.68169284  0.03409155]
#  [-0.02158894 -0.02656786 -3.60085283]
#  [-3.65135958 -0.0056886  -0.0181079 ]]
#
# For site 6, the unmixing matrix W times A is
#
# [[  3.37341339e-02   3.66212578e+00   9.69210353e-03]
#  [ -2.44745554e-02   1.35662156e-02   3.64593407e+00]
#  [  3.60264279e+00  -2.67367749e-04  -1.15446739e-03]]
#
# For site 7, the unmixing matrix W times A is
#
# [[ 0.06457028 -3.59350961  0.0326854 ]
#  [-0.0610038   0.04822361  3.60779762]
#  [ 3.58837121  0.06836873  0.04519502]]
#
# For site 8, the unmixing matrix W times A is
#
# [[  1.63685561e-02  -3.59886738e+00   3.94353240e-02]
#  [ -2.44239383e-02   1.34889664e-02   3.59510393e+00]
#  [  3.65230884e+00   2.43205449e-02  -2.33207676e-04]]
#
# For site 9, the unmixing matrix W times A is
#
# [[ -1.26977973e-02  -3.57091173e+00   4.33937645e-03]
#  [  9.96492859e-03   2.20088595e-03  -3.63698578e+00]
#  [ -3.63844154e+00  -1.03613317e-02   4.00555017e-03]]
#
# None

# %%
np.isinf(-np.inf)
print a['A'].shape, a['S'].shape

# print a['A']

A = a['A']
S = a['S']
A_py = np.zeros(shape=(10,3,3))
S_py = np.zeros(shape=(10,3,10000))


for i in range(3) :
    for k in range(10) :
        for j in range(3) :
            A_py[k,i,j] = A[i,j,k]
        for j in range(10000) :
            S_py[k,i,j] = S[i,j,k]


## Works!!
# print A_py, '\n\n', S_py

## IVA_L.m uses 2 norm for its matrix norm
# np.linalg.norm(A_py[0,:,:], ord=2)

X = S_py.copy()

for k in range(10) :
    X[k,:,:] = np.dot(A_py[k,:,:], S_py[k,:,:])
    
    
print X[0,:,0]

print A_py[0,:,:]

# sqrtYtY = np.sqrt(np.sum(X*X, axis=0))

# print sqrtYtY[:,0]
# Out:
# (3, 3, 10) (3, 10000, 10)
# [ 0.97713712 -0.50484567 -2.19259778]
# [[ 1.17560294 -0.07114317 -0.13899224]
#  [-0.29050038 -0.73918727 -1.30550222]
#  [-1.86191492  0.2460565  -1.11594278]]
